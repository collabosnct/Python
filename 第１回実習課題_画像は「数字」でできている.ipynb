# %% [markdown]
# **🎯課題の目的**

# %% [markdown]
# AI（特にディープラーニング）では、画像や音声をそのまま扱うことはできず、すべて **「数値の配列（行列）」** に変換して計算します。Pythonの数値計算ライブラリ **NumPy（ナンパイ）** を使い、画像を「数字の集まり」として操作する感覚を身につけましょう。

# %% [markdown]
# **🖊準備**

# %% [markdown]
# *   **環境**：Google Colaboratory またはローカルのPython環境
# *   **必須ライブラリ**：`numpy`, `matplotlib`
#
# 以下のコードを実行して、ライブラリを読み込んでおいてください。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **【課題１】Numpyの基礎（配列を作ってみよう）**

# %% [markdown]
# Pythonの標準的な「リスト」と、NumPyの「配列 (ndarray)」は似ていますが、計算の効率や書き方が異なります。以下の操作を行うコードを書いてください。

# %% [markdown]
# 1.   **ベクトル（1次元配列）の作成**：
#
# 　　・要素 [10, 20, 30, 40, 50]を持つNumPy配列 a を作成してください。
#
# 2.   **行列（2次元配列）の作成**：
#
# 　　・以下の 3×3 の行列 b を作成してください。
#
# 　　　[[1, 2, 3],
#
# 　　　 [4, 5, 6],
#
# 　　　 [7, 8, 9]]
#
#
# 3.   **計算**：
#
# 　　・配列 a のすべての要素を**10倍**にした結果を表示してください。（for文を使わずに！）。

# %%
import numpy as np

#1. ベクトルの作成
a = np.array
print

#2. 行列の作成
b = np.array




print

#3. 計算（ブロードキャスト機能）
#Pythonのリストだと [10, 20...] * 10 はリストが10個連結されてしまいますが、
#NumPyなら要素ごとの計算になります。
result =
print

# %% [markdown]
# **【課題２】数字で「絵」を描こう**

# %% [markdown]
# コンピュータにとって、白黒画像は「0（黒）～255（白）の数字が並んだ行列」に過ぎません。NumPyを使って、自分でドット絵を描いてみましょう。

# %% [markdown]
# **Task:**
#
#
# 1.   縦10ピクセル×横10ピクセルの「すべて0（真っ黒）」の配列 `img` を作ってください。
#
# 　　・ヒント：`np.zeros`((高さ, 幅)) を使います。
#
# 2.   その配列の一部（例えば中心付近）に、好きな数字（例えば255など）を代入して、白い四角形や線を描いてください。
#
# 3.   `plt.imshow(img, cmap='gray')`を使って、その配列を画像として表示してください。

# %%
import matplotlib.pyplot as plt

#1. 10×10の黒いキャンバスを作成
img = np.zeros

#2. 配列のインデックスを指定して色を塗る
#例：真ん中に 4×4 の白い四角を描く
#スライス [開始:終了] を使うのがポイントです（終了インデックスは含まれないことに注意）
img

#点を打つ例
img #左上にグレーの点
img #右下にグレーの点

#3. 画像として表示
#cmap='gray'を指定しないと、Matplotlibのデフォルトのカラフルな色で表示されてしまいます
plt.imshow
plt.colorbar  #値のバーを表示するとわかりやすい
plt.show

# %% [markdown]
# **【課題３】画像処理の基礎（ネガポジ反転）**

# %% [markdown]
# ここに、乱数で作った「砂嵐ノイズ画像」があります。この画像の色を **反転（ネガポジ反転）** させるプログラムを書いてください。
#
#
# *   **ルール**：白黒画像の場合、色の反転は 255 - 元の画素値 で計算できます。
# *   **条件**：for文を使わず、NumPyの機能を使って一行で計算してください。

# %%
#‐‐‐準備：砂嵐画像の生成‐‐‐
noise_img = np.random.randint  #0～255の乱数で100×100の画像を作る

#‐‐‐解答‐‐‐
#NumPy配列は、スカラー値との四則演算を一括で行えます。
#255から引くことで、0(黒)は255(白)に、255(白)は0(黒)になります。

#Task: noise_img を反転させた inverted_img を作ってください
inverted_img =  #ここにコードを書く


#表示（元の画像）
plt.figure
plt.subplot
plt.title
plt.imshow

#表示（反転後の画像）
plt.subplot
plt.title
plt.imshow
plt.show

# %% [markdown]
# **【課題４】チャレンジ（カラーの画像の構造）**

# %% [markdown]
# カラー画像は「赤(R)・緑(G)・青(B)」の3枚の層が重なっています。形状 (Shape) は (高さ, 幅, 3) となります。

# %% [markdown]
# **Task:**
#
#
# 1.   `np.zeros((100, 100, 3), dtype=np.uint8)` で100×100の真っ黒なカラー画像を作ってください。
# 2.   画像の **左半分だけを「赤色」** にしてください。
#
#
# *   ヒント：赤にするには [255, 0, 0] を代入します。
# *   スライス機能 `img`[ : , :50] などを活用しましょう。

# %%
#1. カラー画像の器を作成（データ型を uint8 にしておくと画像として扱いやすいです）
color_img = np.zeros

#2. 左半分を赤にする
#構文：[縦の範囲, 横の範囲] = [R, G, B]
# : は「最初から最後まで」、:50 は「最初から50番目まで」
color_img  #赤
