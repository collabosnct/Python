# %%
# データの例
data = [10, 15, 20, 25,30]

# 平均を計算
mean = sum(data) / len(data)
print("平均:", mean)

# 平均偏差を計算
mean_deviation = sum(abs(x - mean) for x in data) / len(data)
print("平均偏差:", mean_deviation)
# Out:
# 平均: 20.0
# 平均偏差: 6.0

# %%
import numpy as np

data = np.array([10, 15, 20, 25, 30])

mean = np.mean(data)
print("平均:", mean)

mean_deviation = np.mean(np.abs(data - mean))
print("平均偏差:", mean_deviation)
# Out:
# 平均: 20.0
# 平均偏差: 6.0

# %%
# データ
data = [10, 15, 20, 25, 30]

# 平均
mean = sum(data) / len(data)

# 分散
variance = sum((x - mean) ** 2 for x in data) / len(data)

print("平均:", mean)
print("分散:", variance)
# Out:
# 平均: 20.0
# 分散: 50.0

# %%
import numpy as np

data = np.array([10, 15, 20, 25, 30])

variance = np.var(data)

print("分散:", variance)
# Out:
# 分散: 50.0

# %%
data_A = [10,12,15,20]
data_B = [8, 9, 11, 13, 14]

def mean_deviation(data):
    mean = sum(data) / len(data)
    abs_dev = [abs(x - mean) for x in data]
    return sum(abs_dev) / len(abs_dev)

mad_A = mean_deviation(data_A)
mad_B = mean_deviation(data_B)

mad_A, mad_B
# Out:
# (3.25, 2.0)

# %%
import numpy as np

data_A = np.array([10, 12, 15, 20])
data_B = np.array([8, 9, 11, 13, 14])

mad_A = np.mean(np.abs(data_A - np.mean(data_A)))
mad_B = np.mean(np.abs(data_B - np.mean(data_B)))

mad_A, mad_B
# Out:
# (np.float64(3.25), np.float64(2.0))

# %%
英語 = [90, 80, 20, 50, 60]
数学 = [70, 10, 80, 70, 60]

def mean_deviation(data):
    mean = sum(data) / len(data)
    abs_dev = [abs(x - mean) for x in data]
    return sum(abs_dev) / len(abs_dev)

mad_英語 = mean_deviation(英語)
mad_数学 = mean_deviation(数学)

mad_英語, mad_数学
# Out:
# (20.0, 19.2)

# %%
import numpy as np

英語 = np.array([90, 80, 20, 50, 60])
数学 = np.array([70, 10, 80, 70, 60])

mad_英語 = np.mean(np.abs(英語 - np.mean(英語)))
mad_数学 = np.mean(np.abs(数学 - np.mean(数学)))

mad_英語, mad_数学
# Out:
# (np.float64(20.0), np.float64(19.2))

# %%
英語 = [90, 80, 20, 50, 60]
数学 = [70, 10, 80, 70, 60]

英語 = sum(英語) / len(英語)
数学 = sum(数学) / len(数学)

英語, 数学
# Out:
# (60.0, 58.0)

# %%
英語 = [90, 80, 20, 50, 60]
数学 = [70, 10, 80, 70, 60]

平均_英語 = sum(英語) / len(英語)
平均_数学 = sum(数学) / len(数学)

分散_英語 = sum((x - 平均_英語)**2 for x in 英語) / len(英語)
分散_数学 = sum((x - 平均_数学)**2 for x in 数学) / len(数学)

分散_英語, 分散_数学
# Out:
# (600.0, 616.0)

# %%
import numpy as np

英語 = np.array([90, 80, 20, 50, 60])
数学 = np.array([70, 10, 80, 70, 60])

分散_英語 = np.var(英語)
分散_数学 = np.var(数学)

分散_英語, 分散_数学
# Out:
# (np.float64(600.0), np.float64(616.0))

# %%
英語 = [90, 80, 20, 50, 60]
数学 = [70, 10, 80, 70, 60]

平均_英語 = sum(英語) / len(英語)
平均_数学 = sum(数学) / len(数学)

分散_英語 = sum((x - 平均_英語)**2 for x in 英語) / len(英語)
分散_数学 = sum((x - 平均_数学)**2 for x in 数学) / len(数学)

import math
標準偏差_英語 = math.sqrt(分散_英語)
標準偏差_数学 = math.sqrt(分散_数学)

標準偏差_英語, 標準偏差_数学
# Out:
# (24.49489742783178, 24.819347291981714)

# %%
import numpy as np

英語 = np.array([90, 80, 20, 50, 60])
数学 = np.array([70, 10, 80, 70, 60])

標準偏差_英語 = np.std(英語)
標準偏差_数学 = np.std(数学)

標準偏差_英語, 標準偏差_数学
# Out:
# (np.float64(24.49489742783178), np.float64(24.819347291981714))

# %%
import matplotlib.pyplot as plt

名前 = ['A', 'B', 'C', 'D', 'E']
英語 = ['90', '80', '20', '50', '60']
数学 = ['70', '10', '80', '70', '60']

英語 = [float(x) for x in 英語]
数学 = [float(x) for x in 数学]

plt.figure(figsize=(6,5))
plt.scatter(英語, 数学, color='blue', s=50)

for i, n in enumerate(名前):
    plt.text(英語[i]+0.3,数学[i]+0.3, n, fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt

名前 = ['A', 'B', 'C', 'D', 'E']
英語 = ['90', '80', '20', '50', '60']
数学 = ['70', '10', '80', '70', '60']

英語 = [float(x) for x in 英語]
数学 = [float(x) for x in 数学]

plt.figure(figsize=(6,5))
plt.scatter(英語, 数学, color='blue', s=50)

for i, n in enumerate(名前):
    plt.text(英語[i]+0.3,数学[i]+0.3, n, fontsize=12)

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'DejaVu Sans'

Name = ['A', 'B', 'C', 'D', 'E']
English = [90, 80, 20, 50, 60]
Mathematics = [70, 10, 80, 70, 60]

English = [float(x) for x in English]
Mathematics = [float(x) for x in Mathematics]

plt.scatter(English, Mathematics, color='blue')

for i, n in enumerate(Name):
    plt.text(English[i]+0.3, Mathematics[i]+0.3, n)

plt.xlabel("English")
plt.ylabel("Mathematics")

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

matplotlib.rcParams['font.family'] = 'DejaVu Sans'

Name = ['A', 'B', 'C', 'D', 'E']
English = [90, 80, 20, 50, 60]
Mathematics = [70, 10, 80, 70, 60]

English = [float(x) for x in English]
Mathematics = [float(x) for x in Mathematics]

plt.scatter(English, Mathematics, color='blue')

for i, n in enumerate(Name):
    plt.text(English[i]+0.3, Mathematics[i]+0.3, n)

slope, intercept = np.polyfit(English, Mathematics, 1)
reg_line = [slope *  x + intercept for x in English]

plt.plot(English, reg_line, color='red', linestyle='--', label='Regression Line')

plt.xlabel("English")
plt.ylabel("Mathematics")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Name = ['A', 'B', 'C', 'D', 'E']
English = np.array([90, 80, 20, 50, 60])
Mathematics = np.array([70, 10, 80, 70, 60])

# 散布図
plt.scatter(English, Mathematics, color='blue')

# 名前表示
for i, n in enumerate(Name):
    plt.text(English[i]+1, Mathematics[i]+1, n)

# 回帰直線の計算
a, b = np.polyfit(English, Mathematics, 1)  # 傾き, 切片

# 回帰直線の描画
x = np.linspace(min(English), max(English), 100)
y = a*x + b
plt.plot(x, y, color='red', label='Regression line')

plt.xlabel("English")
plt.ylabel("Mathematics")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Name = ['A', 'B', 'C', 'D', 'E']
English = np.array([90, 80, 20, 50, 60])
Mathematics = np.array([70, 10, 80, 70, 60])

# 散布図
plt.scatter(English, Mathematics, color='blue')

# 名前表示
for i, n in enumerate(Name):
    plt.text(English[i]+1, Mathematics[i]+1, n)

# 回帰直線の計算
a, b = np.polyfit(English, Mathematics, 1)  # 傾き, 切片

# 回帰直線の描画
x = np.linspace(min(English), max(English), 100)
y = a*x + b
plt.plot(x, y, color='red', label='Regression line')

plt.xlabel("English")
plt.ylabel("Mathematics")
plt.legend()
plt.grid(True)
plt.show()
