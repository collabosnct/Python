# %% [markdown]
# 変数と定数の例

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

a = 1.5  #a:定数
x = np.linspace(-1,1)  #x:変数-1から1の範囲
y = a * x  #y:変数

plt.plot(x, y)
plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()
plt.show()

# %% [markdown]
# 演習

# %%
import numpy as np
import matplotlib.pyplot as plt

b = 3 #b:定数
x = np.linspace(-1,1) #x:変数
y = b * x #y:変数

plt.plot(x, y)
plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()
plt.show()
