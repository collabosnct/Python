# %%
print("Hello, Colab!")
# Out:
# Hello, Colab!

# %%
a = 5
b = 7
print(a + b)
# Out:
# 12

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def greet(name):
    return f"Hello, {name}!"
print(greet("colab"))
# Out:
# Hello, colab!

# %% [markdown]
# これはメモです。
# 今日はPythonの練習をします。

# %% [markdown]
# # 見出し

# %% [markdown]
# ## *小見出し*

# %% [markdown]
# ### *さらに小さい見出し*

# %% [markdown]
# **太字**

# %% [markdown]
# - りんご
# - ばなな
# - みかん

# %%
a = 10
b = 20

result = a + b
print("合計", result)
# Out:
# 合計 30

# %%
def greet(name):
    return f"こんにちは、{name}さん!"

print(greet("田中"))
# Out:
# こんにちは、田中さん!

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
