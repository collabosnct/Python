# %% [markdown]
# 数学の「関数」を、プログラミングの「関数」で実装

# %%
import numpy as np

def my_func(x): #my_funcという名前のPythonの関数で、数式を実装
  return 3*x + 2 #3x + 2

x = 4 #グローバル変数なので、上記の引数xとは別の変数
y = my_func(x) #y = f(x)
print(y)

# %% [markdown]
# 演習

# %%
import numpy as np

def my_func(x):
  return 4*x + 1 #4x + 1

x = 3
y = my_func(x) #y = f(x)
print(y)
